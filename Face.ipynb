# %%
# 필요한 모듈 설치

# !pip install pillow
# !pip install request
# Out:
# ...
# ERROR: Could not find a version that satisfies the requirement request (from versions: none)
# ERROR: No matching distribution found for request

# %%
import matplotlib.pyplot as plt     #그림 관련
import matplotlib.image as mpimg    #사진 관련

# %matplotlib inline

# %%
img = mpimg.imread('이승기.jpg')

plt.figure(figsize = (10, 8))
plt.imshow(img)
plt.show()

# %%
# 유명인과 얼마나 비슷한지 비교

import requests # 인터넷 연결

client_id = "_tdTjPA5heT52O3aoqzS"
client_secret = "AjitGhD2Z0"

url = "https://openapi.naver.com/v1/vision/celebrity"
files = {'image':open('이승기.jpg','rb')}
headers = {'X-Naver-Client-id':client_id, 'X-Naver-Client-secret':client_secret}

response = requests.post(url, files = files, headers = headers)

# %%
import json# json형식을 다루는 모듈

parsed = json.loads(response.text)
print(json.dumps(parsed, indent = 4, sort_keys = False, ensure_ascii = False))

# 사진 한장의 최대 크기는 2MB로 제한
# Out:
# {
#     "info": {
#         "size": {
#             "width": 512,
#             "height": 512
#         },
#         "faceCount": 1
#     },
#     "faces": [
#         {
#             "celebrity": {
#                 "value": "이승기",
#                 "confidence": 1.0
#             }
#         }
#     ]
# }

# %%
# 얼굴 인식, 나이 예측, 감정 상태 분석

import requests # 인터넷 연결

client_id = "_tdTjPA5heT52O3aoqzS"
client_secret = "AjitGhD2Z0"

url = "https://openapi.naver.com/v1/vision/face"
files = {'image':open('마마무.jpg','rb')}
headers = {'X-Naver-Client-id':client_id, 'X-Naver-Client-secret':client_secret}

response = requests.post(url, files = files, headers = headers)

# %%
import json# json형식을 다루는 모듈

parsed = json.loads(response.text)
print(json.dumps(parsed, indent = 4, sort_keys = False, ensure_ascii = False))

# 사진 한장의 최대 크기는 2MB로 제한
# Out:
# {
#     "info": {
#         "size": {
#             "width": 630,
#             "height": 473
#         },
#         "faceCount": 4
#     },
#     "faces": [
#         {
#             "roi": {
#                 "x": 128,
#                 "y": 153,
#                 "width": 63,
#                 "height": 63
#             },
#             "landmark": null,
#             "gender": {
#                 "value": "female",
#                 "confidence": 0.999505
#             },
#             "age": {
#                 "value": "13~17",
#                 "confidence": 0.443581
#             },
#             "emotion": {
#                 "value": "neutral",
#                 "confidence": 0.995437
#             },
#             "pose": {
#                 "value": "part_face",
#                 "confidence": 0.457906
#             }
#         },
#         {
#             "roi": {
#                 "x": 275,
#                 "y": 165,
#                 "width": 38,
# ...

# %%
###################################
# 기본 문법 학습
###################################

# %%
# dict 형과 json에 대해...

dict = {'Name':'pinkwink', 'Age':'None', 'Class':['beginner', 'blog']}
dict
# Out:
# {'Name': 'pinkwink', 'Age': 'None', 'Class': ['beginner', 'blog']}

# %%
dict.keys()
# Out:
# dict_keys(['Name', 'Age', 'Class'])

# %%
dict.values()
# Out:
# dict_values(['pinkwink', 'None', ['beginner', 'blog']])

# %%
dict['Class']
# Out:
# ['beginner', 'blog']

# %%
dict.get('Name')
# Out:
# 'pinkwink'

# %%
dict.get('Age', 'nothing')      # dict에서 Age의 밸류값을 출력, 없으면 'nothing'을 출력
# Out:
# 'None'

# %%
dict.get('Room', 'nothing')
# Out:
# 'nothing'

# %%
#=============================================
# json (Java Script Object Notation)

# %%
customer = {
    'id' : '0001',
    'name' : '홍길동',
    'history' : [
        {'date' : '2019 - 03 - 01', 'log' : True},
        {'date' : '2019 - 03 - 02', 'log' : False},
    ]
}

# %%
import json
json_text = json.dumps(customer, indent = 4, ensure_ascii = False)
print(json_text)
# Out:
# {
#     "id": "0001",
#     "name": "홍길동",
#     "history": [
#         {
#             "date": "2019 - 03 - 01",
#             "log": true
#         },
#         {
#             "date": "2019 - 03 - 02",
#             "log": false
#         }
#     ]
# }

# %%
##########################
# 사진 위에 정보 표시하기
##########################

# %%
img = mpimg.imread('이승기.jpg')

plt.figure(figsize = (10, 8))
plt.imshow(img)
plt.show()

# %%
import requests # 인터넷 연결

client_id = "_tdTjPA5heT52O3aoqzS"
client_secret = "AjitGhD2Z0"

url = "https://openapi.naver.com/v1/vision/face"
files = {'image':open('이승기.jpg','rb')}
headers = {'X-Naver-Client-id':client_id, 'X-Naver-Client-secret':client_secret}

response = requests.post(url, files = files, headers = headers)

# %%
print(response)
# Out:
# <Response [200]>

# %%
import json# json형식을 다루는 모듈

parsed = json.loads(response.text)
print(json.dumps(parsed, indent = 4, sort_keys = False, ensure_ascii = False))

# 사진 한장의 최대 크기는 2MB로 제한
# Out:
# {
#     "info": {
#         "size": {
#             "width": 512,
#             "height": 512
#         },
#         "faceCount": 1
#     },
#     "faces": [
#         {
#             "roi": {
#                 "x": 54,
#                 "y": 143,
#                 "width": 281,
#                 "height": 281
#             },
#             "landmark": {
#                 "leftEye": {
#                     "x": 111,
#                     "y": 204
#                 },
#                 "rightEye": {
#                     "x": 247,
#                     "y": 203
#                 },
#                 "nose": {
#                     "x": 154,
#                     "y": 301
#                 },
#                 "leftMouth": {
#                     "x": 108,
#                     "y": 351
#                 },
#                 "rightMouth": {
#                     "x": 262,
#                     "y": 353
#                 }
#             },
#             "gender": {
# ...

# %%
parsed.keys()
# Out:
# dict_keys(['info', 'faces'])

# %%
parsed['faces']
# Out:
# [{'roi': {'x': 54, 'y': 143, 'width': 281, 'height': 281},
#   'landmark': {'leftEye': {'x': 111, 'y': 204},
#    'rightEye': {'x': 247, 'y': 203},
#    'nose': {'x': 154, 'y': 301},
#    'leftMouth': {'x': 108, 'y': 351},
#    'rightMouth': {'x': 262, 'y': 353}},
#   'gender': {'value': 'male', 'confidence': 0.999948},
#   'age': {'value': '27~31', 'confidence': 0.553023},
#   'emotion': {'value': 'smile', 'confidence': 0.998593},
#   'pose': {'value': 'frontal_face', 'confidence': 0.993573}}]

# %%
parsed['faces'][0]
# Out:
# {'roi': {'x': 54, 'y': 143, 'width': 281, 'height': 281},
#  'landmark': {'leftEye': {'x': 111, 'y': 204},
#   'rightEye': {'x': 247, 'y': 203},
#   'nose': {'x': 154, 'y': 301},
#   'leftMouth': {'x': 108, 'y': 351},
#   'rightMouth': {'x': 262, 'y': 353}},
#  'gender': {'value': 'male', 'confidence': 0.999948},
#  'age': {'value': '27~31', 'confidence': 0.553023},
#  'emotion': {'value': 'smile', 'confidence': 0.998593},
#  'pose': {'value': 'frontal_face', 'confidence': 0.993573}}

# %%
parsed['faces'][0]['roi']       # 얼굴의 위치값
# Out:
# {'x': 54, 'y': 143, 'width': 281, 'height': 281}

# %%
parsed['faces'][0]['gender']        # 성별 값
# Out:
# {'value': 'male', 'confidence': 0.999948}

# %%
parsed['faces'][0]['age']     # 나이 값
# Out:
# {'value': '27~31', 'confidence': 0.553023}

# %%
parsed['faces'][0]['emotion']       # 표정 값
# Out:
# {'value': 'smile', 'confidence': 0.998593}

# %%
x, y, w, h = parsed['faces'][0]['roi'].values()
gender, gen_confi = parsed['faces'][0]['gender'].values()
emotion,emo_confi = parsed['faces'][0]['emotion'].values()
age,age_confi = parsed['faces'][0]['age'].values()

# %%
print(x)
print(y)
print(w)
print(h)
print(gender)
print(gen_confi)
print(emotion)
print(emo_confi)
print(age)
print(age_confi)
# Out:
# 54
# 143
# 281
# 281
# male
# 0.999948
# smile
# 0.998593
# 27~31
# 0.553023

# %%
annotation = gender + " : " + str(gen_confi) + '\n' + emotion + " : " + str(emo_confi) + '\n' + age + " : " + str(age_confi)

# %%
print(annotation)
# Out:
# male : 0.999948
# smile : 0.998593
# 27~31 : 0.553023

# %%
import matplotlib.patches as patches

img = mpimg.imread('이승기.jpg')

fig, ax = plt.subplots(figsize = (10, 10))
ax.imshow(img)                                # ax(액자)에 이미지를 출력

rect_face = patches.Rectangle((x, y), w, h,
                             linewidth = 5,
                             edgecolor = 'r',
                             facecolor = 'none')    # 얼굴 위치 값 계산 및 테두리 색 설정

ax.add_patch(rect_face)

plt.text(350, 400, annotation, wrap = True, fontsize = 17, color = 'Yellow')
plt.show()

# %%
img = mpimg.imread('마마무.jpg')

plt.figure(figsize = (10, 8))
plt.imshow(img)
plt.show()

# %%
import requests # 인터넷 연결

client_id = "_tdTjPA5heT52O3aoqzS"
client_secret = "AjitGhD2Z0"

url = "https://openapi.naver.com/v1/vision/face"
files = {'image':open('마마무.jpg','rb')}
headers = {'X-Naver-Client-id':client_id, 'X-Naver-Client-secret':client_secret}

response = requests.post(url, files = files, headers = headers)

# %%
import json# json형식을 다루는 모듈

parsed = json.loads(response.text)
print(json.dumps(parsed, indent = 4, sort_keys = False, ensure_ascii = False))

# 사진 한장의 최대 크기는 2MB로 제한
# Out:
# {
#     "info": {
#         "size": {
#             "width": 630,
#             "height": 473
#         },
#         "faceCount": 4
#     },
#     "faces": [
#         {
#             "roi": {
#                 "x": 128,
#                 "y": 153,
#                 "width": 63,
#                 "height": 63
#             },
#             "landmark": null,
#             "gender": {
#                 "value": "female",
#                 "confidence": 0.999505
#             },
#             "age": {
#                 "value": "13~17",
#                 "confidence": 0.443581
#             },
#             "emotion": {
#                 "value": "neutral",
#                 "confidence": 0.995437
#             },
#             "pose": {
#                 "value": "part_face",
#                 "confidence": 0.457906
#             }
#         },
#         {
#             "roi": {
#                 "x": 275,
#                 "y": 165,
#                 "width": 38,
# ...

# %%
import matplotlib.patches as patches

img = mpimg.imread('마마무.jpg')

fig, ax = plt.subplots(figsize = (10, 10))
ax.imshow(img)

for each in parsed['faces']:
    x, y, w, h = each['roi'].values()
    gender, gen_confi = each['gender'].values()
    emotion,emo_confi = each['emotion'].values()
    age,age_confi = each['age'].values()
    
    rect_face = patches.Rectangle((x, y), w, h,
                             linewidth = 2,
                             edgecolor = 'r',
                             facecolor = 'none')    # 얼굴 위치 값 계산 및 테두리 색 설정

    ax.add_patch(rect_face)
    
    annotation = gender  + " : " + str(round(gen_confi,4) * 100) + "%" + '\n' + emotion + " : " + str(round(emo_confi,2) * 100) + "%" + '\n' + age + " : " + str(round(age_confi,2)*100) + "%"
    
    plt.text(x, y - 10, annotation, wrap = True, fontsize = 12, color = 'Yellow')
    
plt.show()
